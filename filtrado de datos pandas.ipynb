# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/d3us/Desktop/cursoDataScienceLinkedIn/bd/2008.csv", nrows=100000)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[['Year','Month','DayOfWeek','Cancelled']][:10]
# Out:
#    Year  Month  DayOfWeek  Cancelled
# 0  2008      1          4          0
# 1  2008      1          4          0
# 2  2008      1          4          0
# 3  2008      1          4          0
# 4  2008      1          4          0
# 5  2008      1          4          0
# 6  2008      1          4          0
# 7  2008      1          4          0
# 8  2008      1          4          0
# 9  2008      1          4          0

# %%
#consultas
df[df['ArrDelay']>60].head(20)
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11   2008      1           3          4   1644.0        1510   1845.0
# 30   2008      1           3          4   2107.0        1945   2334.0
# 37   2008      1           3          4   1812.0        1650   1927.0
# 49   2008      1           3          4   2245.0        1730   2354.0
# 77   2008      1           3          4    958.0         900   1052.0
# 81   2008      1           3          4   2248.0        2125    102.0
# 86   2008      1           3          4   1832.0        1655    148.0
# 101  2008      1           3          4   2118.0        2015   2224.0
# 105  2008      1           3          4   2241.0        1910   2340.0
# 121  2008      1           3          4   2232.0        2115    108.0
# 122  2008      1           3          4   1512.0        1315   1802.0
# 135  2008      1           3          4   2255.0        1820    509.0
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df[((df['Year']==2008) & (df['Origin']=='LAX')) & (df['ArrDelay']>100)]
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 372    2008      1           3          4   1820.0        1630   1943.0
# 400    2008      1           3          4   2321.0        1955     38.0
# 402    2008      1           3          4   2008.0        1805   2139.0
# 403    2008      1           3          4   1625.0        1430   1748.0
# 404    2008      1           3          4   1305.0        1050   1421.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 92083  2008      1          31          4   1503.0        1255   1709.0
# 92093  2008      1          31          4   1123.0         910   1248.0
# 92098  2008      1          31          4   1957.0        1725   2129.0
# 92101  2008      1          31          4   1722.0        1525   1829.0
# 92121  2008      1          31          4   2050.0        1900   2213.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
