# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/d3us/Desktop/cursoDataScienceLinkedIn/bd/2008.csv", nrows=100000)
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
dfLAS=df[df["Origin"]=='LAS']
dfHOU=df[df["Origin"]=='HOU']
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 3269   2008      1           4          5   1910.0        1910   2025.0
# 3270   2008      1           4          5   1345.0        1345   1453.0
# 3271   2008      1           4          5    736.0         735    839.0
# 3272   2008      1           4          5   1603.0        1550   1647.0
# 3273   2008      1           4          5   2105.0        2105   2151.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 91668  2008      1          31          4   1155.0         845   1539.0
# 91669  2008      1          31          4    651.0         655    825.0
# 91670  2008      1          31          4   1654.0        1630   1829.0
# 91671  2008      1          31          4   1233.0        1120   1425.0
# 91672  2008      1          31          4   2119.0        1950   2241.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
newDF= dfLAS.append(dfHOU) #uniendo las 2 bases de datos o dataframes
newDF.Origin
# Out:
# 79       LAS
# 80       LAS
# 81       LAS
# 82       LAS
# 83       LAS
#         ...
# 91668    HOU
# 91669    HOU
# 91670    HOU
# 91671    HOU
# 91672    HOU
# Name: Origin, Length: 10642, dtype: object
